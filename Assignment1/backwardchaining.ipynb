# %%
import pandas as pd

# %%
df = pd.read_csv('iris.data', header=None, names=["SL", "SW", "PL", "PW", "type"], index_col=False)

# %%
def classifyPrediction(row):
    if row["PL"] >= 1 and row["PL"] <= 1.9 and row["PW"] >= 0.1 and row["PW"] <= 0.6:
        return "Iris-setosa"
    elif row["PL"] >= 3 and row["PL"] <= 5.1 and row["PW"] >= 1 and row["PW"] <= 1.8:
        return "Iris-versicolor"
    elif row["PL"] >= 4.5 and row["PL"] <= 6.9 and row["PW"] >= 1.4 and row["PW"] <= 2.5:
        return "Iris-virginica"

# %%
df["predicted-type"] = df.apply(classifyPrediction, axis=1)
df
# Out:
#       SL   SW   PL   PW            type   predicted-type
# 0    5.1  3.5  1.4  0.2     Iris-setosa      Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa      Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa      Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa      Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa      Iris-setosa
# ..   ...  ...  ...  ...             ...              ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica   Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica   Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica   Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica   Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica  Iris-versicolor
#
# [150 rows x 6 columns]

# %%
y_true = df["type"]
x_predicted = df["predicted-type"]

df_confusion = pd.crosstab(y_true, x_predicted, margins=True)
df_confusion
# Out:
# predicted-type   Iris-setosa  Iris-versicolor  Iris-virginica  All
# type
# Iris-setosa               50                0               0   50
# Iris-versicolor            0               50               0   50
# Iris-virginica             0                8              42   50
# All                       50               58              42  150
